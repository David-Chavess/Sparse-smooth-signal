# %%
from src import *
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
d = (64, 64)
seed = 11
s = SparseSmoothSignal(d)
s.random_sparse(seed)
s.random_smooth(seed)
s.plot()

# %%
test_noise(s=s, psnr_min=0., psnr_max=60., nb=60, L=0.25, lambda_=0.1, theta=0.1, operator_l2='L')
# Out:
# Best value L1: 52.88135593220339
# Best value L2: 28.47457627118644

# %%
test_noise(s=s, psnr_min=0., psnr_max=60., nb=60, L=0.25, lambda_=0.1, theta=0.3, operator_l2='L')
# Out:
# Best value L1: 57.96610169491525
# Best value L2: 28.47457627118644

# %%
test_noise(s=s, psnr_min=0., psnr_max=60., nb=60, L=0.25, lambda_=0.3, theta=0.1, operator_l2='L')
# Out:
# Best value L1: 38.644067796610166
# Best value L2: 28.47457627118644

# %%
test_noise(s=s, psnr_min=0., psnr_max=60., nb=60, L=0.25, lambda_=0.3, theta=0.3, operator_l2='L')
# Out:
# Best value L1: 32.54237288135593
# Best value L2: 56.94915254237288

# %%
test_numbers_of_measurements(s=s, L_min=0.01, L_max=0.75, nb=50, lambda_=0.1, theta=0.1, operator_l2='L', psnr=30.)
# Out:
# Best value L1: 0.75
# Best value L2: 0.6593877551020408

# %%
test_numbers_of_measurements(s=s, L_min=0.01, L_max=0.75, nb=50, lambda_=0.1, theta=0.3, operator_l2='L', psnr=30.)
# Out:
# Best value L1: 0.719795918367347
# Best value L2: 0.6895918367346939

# %%
test_numbers_of_measurements(s=s, L_min=0.01, L_max=0.75, nb=50, lambda_=0.3, theta=0.1, operator_l2='L', psnr=30.)
# Out:
# Best value L1: 0.75
# Best value L2: 0.75

# %%
test_numbers_of_measurements(s=s, L_min=0.01, L_max=0.75, nb=50, lambda_=0.3, theta=0.3, operator_l2='L', psnr=30.)
# Out:
# Best value L1: 0.5838775510204082
# Best value L2: 0.7348979591836735

# %%
test_thetas(s=s, theta_min=0.001, theta_max=0.9, nb=50, L=0.25, lambda_=0.1, operator_l2='L', psnr=30.)
# Out:
# Best value L1: 0.5697551020408164
# Best value L2: 0.056040816326530615

# %%
test_thetas(s=s, theta_min=0.005, theta_max=0.9, nb=50, L=0.25, lambda_=0.2, operator_l2='L', psnr=30.)
# Out:
# Best value L1: 0.2972448979591837
# Best value L2: 0.4798979591836735

# %%
test_thetas(s=s, theta_min=0.005, theta_max=0.9, nb=50, L=0.25, lambda_=0.3, operator_l2='L', psnr=50.)
# Out:
# Best value L1: 0.04153061224489796
# Best value L2: 0.3703061224489796

# %%
test_lambdas(s=s, lambda_min=0.01, lambda_max=0.5, nb=50, L=0.25, theta=0.1, operator_l2='L', psnr=30.)
# Out:
# Best value L1: 0.5
# Best value L2: 0.17

# %%
test_lambdas(s=s, lambda_min=0.01, lambda_max=0.5, nb=50, L=0.25, theta=0.2, operator_l2='L', psnr=30.)
# Out:
# Best value L1: 0.34
# Best value L2: 0.13

# %%
test_lambdas(s=s, lambda_min=0.01, lambda_max=5, nb=50, L=0.25, theta=0.2, operator_l2='L', psnr=30.)
# Out:
# Best value L1: 0.31551020408163266
# Best value L2: 0.4173469387755102

# %%
test_lambdas(s=s, lambda_min=0.01, lambda_max=5, nb=50, L=0.25, theta=0.5, operator_l2='L', psnr=30.)
# Out:
# Best value L1: 0.11183673469387755
# Best value L2: 0.11183673469387755

# %%
test_lambdas(s=s, lambda_min=0.01, lambda_max=5, nb=50, L=0.25, theta=0.1, operator_l2='L', psnr=50.)
# Out:
# Best value L1: 0.11183673469387755
# Best value L2: 0.01
